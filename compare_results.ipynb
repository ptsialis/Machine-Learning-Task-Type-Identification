# %%
from utils.compare import *
from pathlib import Path

# %%
#root_folder = Path("Exp2/Exp2_Val_all/")
root_folder = Path("Exp2/Exp2_Results/Qwen")
save_dir = Path("Plots")

# %%
summary_table_runs=  collect_runs(root_folder)
summary_table = make_summary_table(summary_table_runs)
summary_table_sorted = summary_table.sort_values("f1_macro", ascending=False)

# %%
summary_table_sorted
# Out:
#                                               run_name  \
# 115  gpt-5_Train_few_shot_Reasoning_Dataset_seriali...
# 112  gpt-5_Train_few_shot_Reasoning_Dataset_seriali...
# 116  gpt-5_Train_few_shot_Reasoning_Dataset_seriali...
# 128  gpt-5_Train_zero_shot_Reasoning_Dataset_serial...
# 108  gpt-5_Train_few_shot_NoReasoning_Dataset_seria...
# ..                                                 ...
# 98   Qwen3-14B_Train_few_shot_Reasoning_Dataset_ser...
# 72   Qwen3-14B_Train_few_shot_Reasoning_Dataset_ser...
# 69   Qwen3-14B_Train_few_shot_Reasoning_Dataset_ser...
# 92   Qwen3-14B_Train_few_shot_Reasoning_Dataset_ser...
# 95   Qwen3-14B_Train_few_shot_Reasoning_Dataset_ser...
#
#                                         hyperparameter  completion_rate  \
# 115  gpt-5_Train_few_shot_Reasoning_Dataset_seriali...            100.0
# 112  gpt-5_Train_few_shot_Reasoning_Dataset_seriali...            100.0
# 116  gpt-5_Train_few_shot_Reasoning_Dataset_seriali...            100.0
# ...

# %%
fig_viol = plot_f1_violin_combined(
    df=summary_table,
    run_name_col="run_name",
    f1_col="f1_macro",
    save_dir=save_dir,
    save=True,
)

fig_viol.show()

# %%
fig_box = plot_f1_box_combined(
    df=summary_table,
    run_name_col="run_name",
    f1_col="f1_macro",
    save_dir=save_dir,
    save=True,
)

fig_box.show()

# %%
fig = plot_f1_box_by_model_name(
    df=summary_table,
    run_name_col="run_name",
    f1_col="f1_macro",
    save_dir=save_dir,
    save=True,
)

fig.show()

# %%
fig = plot_f1_box_by_reasoning(
    df=summary_table,
    run_name_col="run_name",
    f1_col="f1_macro",
    save_dir=save_dir,
    save=True,
)

fig.show()

# %%
fig = plot_f1_box_by_shot(
    df=summary_table,
    run_name_col="run_name",
    f1_col="f1_macro",
    save_dir=save_dir,
    save=True,
)

fig.show()

# %%
fig = plot_f1_box_by_after_name(
    df=summary_table,
    run_name_col="run_name",
    f1_col="f1_macro",
    save_dir=save_dir,
    save=True,
)

fig.show()

# %%
fig = plot_f1_box_by_last_parts(
    df=summary_table,
    run_name_col="run_name",
    f1_col="f1_macro",
    save_dir=save_dir,
    save=True,
)

fig.show()
# Out:
# Final order: ['g5_rows25', 'g5_rows50', 'g5_rows100', 'g10_rows25', 'g10_rows50', 'g10_rows100', 'Full_rows25', 'Full_rows50', 'Full_rows100']

# %%
avg_after_name = average_f1_by_after_name(
    df=summary_table,
    run_name_col="run_name",
    f1_col="f1_macro",
)

avg_after_name
# Out:
#                           after_name  mean_f1_score  n_runs
# 0  dataset_description+unique_target       0.814565      52
# 1                dataset_description       0.758132      26
# 2                         BasePrompt       0.572911      27
# 3                      unique_target       0.568663      27

# %%
fig = plot_average_f1_by_last_parts(
    summary_df=summary_table,
    n_parts=2,
    run_name_col="run_name",
    f1_col="f1_macro",
    save_dir=save_dir,
    save=True,
)

fig.show()
# Out:
# Detected group_key values: ['Full_rows100', 'Full_rows25', 'Full_rows50', 'g10_rows100', 'g10_rows25', 'g10_rows50', 'g5_rows100', 'g5_rows25', 'g5_rows50']
# Final plotting order: ['g5_rows25', 'g5_rows50', 'g5_rows100', 'g10_rows25', 'g10_rows50', 'g10_rows100', 'Full_rows25', 'Full_rows50', 'Full_rows100']
