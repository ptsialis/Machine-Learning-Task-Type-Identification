# %%
import pandas as pd

# %%
df_name = "df_time_few_shot.csv"
df = pd.read_csv(df_name)
df
# Out:
#    Unnamed: 0          dataset_name problem_type sub_problem_type  \
# 0           0  UWaveGestureLibraryX  Time_Series       multiclass
# 1           1    SelfRegulationSCP2  Time_Series           binary
# 2           2        planning-relax  Time_Series       regression
#
#   multi_uni_variate                                          file_path  \
# 0        Univariate  ../dataset/timeseries_datasets_for_experiments...
# 1      Multivariate  ../dataset/timeseries_datasets_for_experiments...
# 2      Multivariate  ../dataset/timeseries_datasets_for_experiments...
#
#                               original_download_link target_variable  \
# 0  https://www.timeseriesclassification.com/datas...          target
# 1  https://www.timeseriesclassification.com/datas...        cortical
# 2  https://openml.org/data/v1/download/1592282/pl...          target
#
#   target_variable_direction multi_target target_variable_data_type  \
# ...

# %%
df = df.drop(columns=["Unnamed: 0" ,"Unnamed: 16", "dataset_format","if_timeseries_one_or more_timeseries","multi_target","target_variable_data_type"])

# %%
df.to_csv(df_name, index=False)
