# %%
import pandas as pd

# %%
import pandas as pd

df_name = "exp2_test.csv"
df = pd.read_csv(df_name)

# %%
df
# Out:
#                      dataset_name problem_type sub_problem_type  \
# 0              AllGestureWiimoteX  Time_Series       multiclass
# 1    MiddlePhalanxOutlineAgeGroup  Time_Series       multiclass
# 2              SelfRegulationSCP1  Time_Series           binary
# 3                           colic      Tabular           binary
# 4                            wilt      Tabular           binary
# ..                            ...          ...              ...
# 371                      visitors  Time_Series       regression
# 372                      fruitfly      Tabular       regression
# 373                planning-relax      Tabular           binary
# 374                       Twitter  Time_Series       regression
# 375                       segment      Tabular       multiclass
#
#         multi_uni_variate                                          file_path  \
# 0              Univariate  ../dataset/timeseries_datasets_for_experiments...
# ...
